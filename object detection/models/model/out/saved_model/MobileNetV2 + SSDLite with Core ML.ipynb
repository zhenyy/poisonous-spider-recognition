# %%
import tensorflow as tf
from tensorflow.python.tools import strip_unused_lib
from tensorflow.python.framework import dtypes
from tensorflow.python.platform import gfile
import numpy as np
import tfcoreml
import coremltools
from coremltools.models import datatypes
from coremltools.models import neural_network
from coremltools.models.pipeline import *

# %% [markdown]
# ### Converting from TensorFlow
#
# First, load the SavedModel into a new TensorFlow graph object:

# %%
def load_saved_model(path):
    the_graph = tf.Graph()
    with tf.Session(graph=the_graph) as sess:
        tf.saved_model.loader.load(sess, 
                [tf.saved_model.tag_constants.SERVING], path)
    return the_graph

# %%
saved_model_path = ""
the_graph = load_saved_model(saved_model_path)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:The specified SavedModel has no variables; no checkpoints were restored.

# %% [markdown]
# Next, we’ll use a helper function to strip away unused subgraphs and save the result as another frozen model:

# %%
frozen_model_file = "frozen_model.pb"       
input_node = "Preprocessor/sub"
bbox_output_node = "concat"
class_output_node = "Postprocessor/convert_scores"

# %%
def optimize_graph(graph):
    gdef = strip_unused_lib.strip_unused(
            input_graph_def = graph.as_graph_def(),
            input_node_names = [input_node],
            output_node_names = [bbox_output_node, class_output_node],
            placeholder_type_enum = dtypes.float32.as_datatype_enum)

    with gfile.GFile(frozen_model_file, "wb") as f:
        f.write(gdef.SerializeToString())

# %%
optimize_graph(the_graph)
# Out:
# WARNING:tensorflow:From /home/donghany/.local/lib/python3.6/site-packages/tensorflow/python/tools/strip_unused_lib.py:86: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph

# %% [markdown]
# Now we’ve got something that tfcoreml will be happy with. To convert the frozen TensorFlow graph to Core ML, do the following:

# %%
coreml_model_path = "MobileNetV2_SSDLite.mlmodel"

input_width = 300
input_height = 300

input_tensor = input_node + ":0"
bbox_output_tensor = bbox_output_node + ":0"
class_output_tensor = class_output_node + ":0"

ssd_model = tfcoreml.convert(
    tf_model_path=frozen_model_file,
    mlmodel_path=coreml_model_path,
    input_name_shape_dict={ input_tensor: [1, input_height, input_width, 3] },
    image_input_names=input_tensor,
    output_feature_names=[bbox_output_tensor, class_output_tensor],
    is_bgr=False,
    red_bias=-1.0,
    green_bias=-1.0,
    blue_bias=-1.0,
    image_scale=2./255)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Collecting all the 'Const' ops from the graph, by running it....
# Done.
# Now finding ops in the TF graph that can be dropped for inference
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob Preprocessor/sub:0
# 1/1260: Analysing op name: Postprocessor/scale_logits/y ( type:  Const )
# 2/1260: Analysing op name: concat_1/axis ( type:  Const )
# 3/1260: Analysing op name: concat/axis ( type:  Const )
# 4/1260: Analysing op name: BoxPredictor_5/Reshape_1/shape/2 ( type:  Const )
# 5/1260: Analysing op name: BoxPredictor_5/Reshape_1/shape/1 ( type:  Const )
# 6/1260: Analysing op name: BoxPredictor_5/strided_slice_1/stack_2 ( type:  Const )
# 7/1260: Analysing op name: BoxPredictor_5/strided_slice_1/stack_1 ( type:  Const )
# 8/1260: Analysing op name: BoxPredictor_5/strided_slice_1/stack ( type:  Const )
# 9/1260: Analysing op name: BoxPredictor_5/ClassPredictor/biases ( type:  Const )
# 10/1260: Analysing op name: BoxPredictor_5/ClassPredictor/biases/read ( type:  Identity )
# 11/1260: Analysing op name: BoxPredictor_5/ClassPredictor/weights ( type:  Const )
# 12/1260: Analysing op name: BoxPredictor_5/ClassPredictor/weights/read ( type:  Identity )
# 13/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 14/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 15/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 16/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 17/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 18/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 19/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 20/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 21/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/depthwise_weights ( type:  Const )
# 22/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 23/1260: Analysing op name: BoxPredictor_5/Reshape/shape/3 ( type:  Const )
# 24/1260: Analysing op name: BoxPredictor_5/Reshape/shape/2 ( type:  Const )
# 25/1260: Analysing op name: BoxPredictor_5/Reshape/shape/1 ( type:  Const )
# 26/1260: Analysing op name: BoxPredictor_5/strided_slice/stack_2 ( type:  Const )
# 27/1260: Analysing op name: BoxPredictor_5/strided_slice/stack_1 ( type:  Const )
# 28/1260: Analysing op name: BoxPredictor_5/strided_slice/stack ( type:  Const )
# 29/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/biases ( type:  Const )
# 30/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/biases/read ( type:  Identity )
# 31/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/weights ( type:  Const )
# 32/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/weights/read ( type:  Identity )
# 33/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 34/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 35/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 36/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 37/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 38/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 39/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 40/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 41/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/depthwise_weights ( type:  Const )
# 42/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 43/1260: Analysing op name: BoxPredictor_4/Reshape_1/shape/2 ( type:  Const )
# 44/1260: Analysing op name: BoxPredictor_4/Reshape_1/shape/1 ( type:  Const )
# 45/1260: Analysing op name: BoxPredictor_4/strided_slice_1/stack_2 ( type:  Const )
# 46/1260: Analysing op name: BoxPredictor_4/strided_slice_1/stack_1 ( type:  Const )
# 47/1260: Analysing op name: BoxPredictor_4/strided_slice_1/stack ( type:  Const )
# 48/1260: Analysing op name: BoxPredictor_4/ClassPredictor/biases ( type:  Const )
# 49/1260: Analysing op name: BoxPredictor_4/ClassPredictor/biases/read ( type:  Identity )
# 50/1260: Analysing op name: BoxPredictor_4/ClassPredictor/weights ( type:  Const )
# 51/1260: Analysing op name: BoxPredictor_4/ClassPredictor/weights/read ( type:  Identity )
# 52/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 53/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 54/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 55/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 56/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 57/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 58/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 59/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 60/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/depthwise_weights ( type:  Const )
# 61/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 62/1260: Analysing op name: BoxPredictor_4/Reshape/shape/3 ( type:  Const )
# 63/1260: Analysing op name: BoxPredictor_4/Reshape/shape/2 ( type:  Const )
# 64/1260: Analysing op name: BoxPredictor_4/Reshape/shape/1 ( type:  Const )
# 65/1260: Analysing op name: BoxPredictor_4/strided_slice/stack_2 ( type:  Const )
# 66/1260: Analysing op name: BoxPredictor_4/strided_slice/stack_1 ( type:  Const )
# 67/1260: Analysing op name: BoxPredictor_4/strided_slice/stack ( type:  Const )
# 68/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/biases ( type:  Const )
# 69/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/biases/read ( type:  Identity )
# 70/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/weights ( type:  Const )
# 71/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/weights/read ( type:  Identity )
# 72/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 73/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 74/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 75/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 76/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 77/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 78/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 79/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 80/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/depthwise_weights ( type:  Const )
# 81/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 82/1260: Analysing op name: BoxPredictor_3/Reshape_1/shape/2 ( type:  Const )
# 83/1260: Analysing op name: BoxPredictor_3/Reshape_1/shape/1 ( type:  Const )
# 84/1260: Analysing op name: BoxPredictor_3/strided_slice_1/stack_2 ( type:  Const )
# 85/1260: Analysing op name: BoxPredictor_3/strided_slice_1/stack_1 ( type:  Const )
# 86/1260: Analysing op name: BoxPredictor_3/strided_slice_1/stack ( type:  Const )
# 87/1260: Analysing op name: BoxPredictor_3/ClassPredictor/biases ( type:  Const )
# 88/1260: Analysing op name: BoxPredictor_3/ClassPredictor/biases/read ( type:  Identity )
# 89/1260: Analysing op name: BoxPredictor_3/ClassPredictor/weights ( type:  Const )
# 90/1260: Analysing op name: BoxPredictor_3/ClassPredictor/weights/read ( type:  Identity )
# 91/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 92/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 93/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 94/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 95/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 96/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 97/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 98/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 99/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/depthwise_weights ( type:  Const )
# 100/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 101/1260: Analysing op name: BoxPredictor_3/Reshape/shape/3 ( type:  Const )
# 102/1260: Analysing op name: BoxPredictor_3/Reshape/shape/2 ( type:  Const )
# 103/1260: Analysing op name: BoxPredictor_3/Reshape/shape/1 ( type:  Const )
# 104/1260: Analysing op name: BoxPredictor_3/strided_slice/stack_2 ( type:  Const )
# 105/1260: Analysing op name: BoxPredictor_3/strided_slice/stack_1 ( type:  Const )
# 106/1260: Analysing op name: BoxPredictor_3/strided_slice/stack ( type:  Const )
# 107/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/biases ( type:  Const )
# 108/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/biases/read ( type:  Identity )
# 109/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/weights ( type:  Const )
# 110/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/weights/read ( type:  Identity )
# 111/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 112/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 113/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 114/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 115/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 116/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 117/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 118/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 119/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/depthwise_weights ( type:  Const )
# 120/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 121/1260: Analysing op name: BoxPredictor_2/Reshape_1/shape/2 ( type:  Const )
# 122/1260: Analysing op name: BoxPredictor_2/Reshape_1/shape/1 ( type:  Const )
# 123/1260: Analysing op name: BoxPredictor_2/strided_slice_1/stack_2 ( type:  Const )
# 124/1260: Analysing op name: BoxPredictor_2/strided_slice_1/stack_1 ( type:  Const )
# 125/1260: Analysing op name: BoxPredictor_2/strided_slice_1/stack ( type:  Const )
# 126/1260: Analysing op name: BoxPredictor_2/ClassPredictor/biases ( type:  Const )
# 127/1260: Analysing op name: BoxPredictor_2/ClassPredictor/biases/read ( type:  Identity )
# 128/1260: Analysing op name: BoxPredictor_2/ClassPredictor/weights ( type:  Const )
# 129/1260: Analysing op name: BoxPredictor_2/ClassPredictor/weights/read ( type:  Identity )
# 130/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 131/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 132/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 133/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 134/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 135/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 136/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 137/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 138/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/depthwise_weights ( type:  Const )
# 139/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 140/1260: Analysing op name: BoxPredictor_2/Reshape/shape/3 ( type:  Const )
# 141/1260: Analysing op name: BoxPredictor_2/Reshape/shape/2 ( type:  Const )
# 142/1260: Analysing op name: BoxPredictor_2/Reshape/shape/1 ( type:  Const )
# 143/1260: Analysing op name: BoxPredictor_2/strided_slice/stack_2 ( type:  Const )
# 144/1260: Analysing op name: BoxPredictor_2/strided_slice/stack_1 ( type:  Const )
# 145/1260: Analysing op name: BoxPredictor_2/strided_slice/stack ( type:  Const )
# 146/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/biases ( type:  Const )
# 147/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/biases/read ( type:  Identity )
# 148/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/weights ( type:  Const )
# 149/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/weights/read ( type:  Identity )
# 150/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 151/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 152/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 153/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 154/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 155/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 156/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 157/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 158/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/depthwise_weights ( type:  Const )
# 159/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 160/1260: Analysing op name: BoxPredictor_1/Reshape_1/shape/2 ( type:  Const )
# 161/1260: Analysing op name: BoxPredictor_1/Reshape_1/shape/1 ( type:  Const )
# 162/1260: Analysing op name: BoxPredictor_1/strided_slice_1/stack_2 ( type:  Const )
# 163/1260: Analysing op name: BoxPredictor_1/strided_slice_1/stack_1 ( type:  Const )
# 164/1260: Analysing op name: BoxPredictor_1/strided_slice_1/stack ( type:  Const )
# 165/1260: Analysing op name: BoxPredictor_1/ClassPredictor/biases ( type:  Const )
# 166/1260: Analysing op name: BoxPredictor_1/ClassPredictor/biases/read ( type:  Identity )
# 167/1260: Analysing op name: BoxPredictor_1/ClassPredictor/weights ( type:  Const )
# 168/1260: Analysing op name: BoxPredictor_1/ClassPredictor/weights/read ( type:  Identity )
# 169/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 170/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 171/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 172/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 173/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 174/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 175/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 176/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 177/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/depthwise_weights ( type:  Const )
# 178/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 179/1260: Analysing op name: BoxPredictor_1/Reshape/shape/3 ( type:  Const )
# 180/1260: Analysing op name: BoxPredictor_1/Reshape/shape/2 ( type:  Const )
# 181/1260: Analysing op name: BoxPredictor_1/Reshape/shape/1 ( type:  Const )
# 182/1260: Analysing op name: BoxPredictor_1/strided_slice/stack_2 ( type:  Const )
# 183/1260: Analysing op name: BoxPredictor_1/strided_slice/stack_1 ( type:  Const )
# 184/1260: Analysing op name: BoxPredictor_1/strided_slice/stack ( type:  Const )
# 185/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/biases ( type:  Const )
# 186/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/biases/read ( type:  Identity )
# 187/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/weights ( type:  Const )
# 188/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/weights/read ( type:  Identity )
# 189/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 190/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 191/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 192/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 193/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 194/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 195/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 196/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 197/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/depthwise_weights ( type:  Const )
# 198/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 199/1260: Analysing op name: BoxPredictor_0/Reshape_1/shape/2 ( type:  Const )
# 200/1260: Analysing op name: BoxPredictor_0/Reshape_1/shape/1 ( type:  Const )
# 201/1260: Analysing op name: BoxPredictor_0/strided_slice_1/stack_2 ( type:  Const )
# 202/1260: Analysing op name: BoxPredictor_0/strided_slice_1/stack_1 ( type:  Const )
# 203/1260: Analysing op name: BoxPredictor_0/strided_slice_1/stack ( type:  Const )
# 204/1260: Analysing op name: BoxPredictor_0/ClassPredictor/biases ( type:  Const )
# 205/1260: Analysing op name: BoxPredictor_0/ClassPredictor/biases/read ( type:  Identity )
# 206/1260: Analysing op name: BoxPredictor_0/ClassPredictor/weights ( type:  Const )
# 207/1260: Analysing op name: BoxPredictor_0/ClassPredictor/weights/read ( type:  Identity )
# 208/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 209/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 210/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 211/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 212/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 213/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 214/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 215/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 216/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/depthwise_weights ( type:  Const )
# 217/1260: Analysing op name: BoxPredictor_0/ClassPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 218/1260: Analysing op name: BoxPredictor_0/Reshape/shape/3 ( type:  Const )
# 219/1260: Analysing op name: BoxPredictor_0/Reshape/shape/2 ( type:  Const )
# 220/1260: Analysing op name: BoxPredictor_0/Reshape/shape/1 ( type:  Const )
# 221/1260: Analysing op name: BoxPredictor_0/strided_slice/stack_2 ( type:  Const )
# 222/1260: Analysing op name: BoxPredictor_0/strided_slice/stack_1 ( type:  Const )
# 223/1260: Analysing op name: BoxPredictor_0/strided_slice/stack ( type:  Const )
# 224/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/biases ( type:  Const )
# 225/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/biases/read ( type:  Identity )
# 226/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/weights ( type:  Const )
# 227/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor/weights/read ( type:  Identity )
# 228/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance ( type:  Const )
# 229/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 230/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean ( type:  Const )
# 231/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 232/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/beta ( type:  Const )
# 233/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/beta/read ( type:  Identity )
# 234/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/gamma ( type:  Const )
# 235/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 236/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/depthwise_weights ( type:  Const )
# 237/1260: Analysing op name: BoxPredictor_0/BoxEncodingPredictor_depthwise/depthwise_weights/read ( type:  Identity )
# 238/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_variance ( type:  Const )
# 239/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_variance/read ( type:  Identity )
# 240/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_mean ( type:  Const )
# 241/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/moving_mean/read ( type:  Identity )
# 242/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/beta ( type:  Const )
# 243/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/beta/read ( type:  Identity )
# 244/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/gamma ( type:  Const )
# 245/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/gamma/read ( type:  Identity )
# 246/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/weights ( type:  Const )
# 247/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/weights/read ( type:  Identity )
# 248/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_variance ( type:  Const )
# 249/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 250/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_mean ( type:  Const )
# 251/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 252/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/beta ( type:  Const )
# 253/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/beta/read ( type:  Identity )
# 254/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/gamma ( type:  Const )
# 255/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 256/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/depthwise_weights ( type:  Const )
# 257/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/depthwise_weights/read ( type:  Identity )
# 258/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_variance ( type:  Const )
# 259/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_variance/read ( type:  Identity )
# 260/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_mean ( type:  Const )
# 261/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/moving_mean/read ( type:  Identity )
# 262/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/beta ( type:  Const )
# 263/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/beta/read ( type:  Identity )
# 264/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/gamma ( type:  Const )
# 265/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/gamma/read ( type:  Identity )
# 266/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/weights ( type:  Const )
# 267/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/weights/read ( type:  Identity )
# 268/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_variance ( type:  Const )
# 269/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_variance/read ( type:  Identity )
# 270/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_mean ( type:  Const )
# 271/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/moving_mean/read ( type:  Identity )
# 272/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/beta ( type:  Const )
# 273/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/beta/read ( type:  Identity )
# 274/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/gamma ( type:  Const )
# 275/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/gamma/read ( type:  Identity )
# 276/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/weights ( type:  Const )
# 277/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/weights/read ( type:  Identity )
# 278/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_variance ( type:  Const )
# 279/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 280/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_mean ( type:  Const )
# 281/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 282/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/beta ( type:  Const )
# 283/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/beta/read ( type:  Identity )
# 284/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/gamma ( type:  Const )
# 285/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 286/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/depthwise_weights ( type:  Const )
# 287/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/depthwise_weights/read ( type:  Identity )
# 288/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_variance ( type:  Const )
# 289/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_variance/read ( type:  Identity )
# 290/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_mean ( type:  Const )
# 291/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/moving_mean/read ( type:  Identity )
# 292/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/beta ( type:  Const )
# 293/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/beta/read ( type:  Identity )
# 294/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/gamma ( type:  Const )
# 295/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/gamma/read ( type:  Identity )
# 296/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/weights ( type:  Const )
# 297/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/weights/read ( type:  Identity )
# 298/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_variance ( type:  Const )
# 299/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_variance/read ( type:  Identity )
# 300/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_mean ( type:  Const )
# 301/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/moving_mean/read ( type:  Identity )
# 302/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/beta ( type:  Const )
# 303/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/beta/read ( type:  Identity )
# 304/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/gamma ( type:  Const )
# 305/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/gamma/read ( type:  Identity )
# 306/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/weights ( type:  Const )
# 307/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/weights/read ( type:  Identity )
# 308/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_variance ( type:  Const )
# 309/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 310/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_mean ( type:  Const )
# 311/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 312/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/beta ( type:  Const )
# 313/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/beta/read ( type:  Identity )
# 314/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/gamma ( type:  Const )
# 315/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 316/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/depthwise_weights ( type:  Const )
# 317/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/depthwise_weights/read ( type:  Identity )
# 318/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_variance ( type:  Const )
# 319/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_variance/read ( type:  Identity )
# 320/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_mean ( type:  Const )
# 321/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/moving_mean/read ( type:  Identity )
# 322/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/beta ( type:  Const )
# 323/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/beta/read ( type:  Identity )
# 324/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/gamma ( type:  Const )
# 325/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/gamma/read ( type:  Identity )
# 326/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/weights ( type:  Const )
# 327/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/weights/read ( type:  Identity )
# 328/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_variance ( type:  Const )
# 329/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_variance/read ( type:  Identity )
# 330/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_mean ( type:  Const )
# 331/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/moving_mean/read ( type:  Identity )
# 332/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/beta ( type:  Const )
# 333/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/beta/read ( type:  Identity )
# 334/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/gamma ( type:  Const )
# 335/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/gamma/read ( type:  Identity )
# 336/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/weights ( type:  Const )
# 337/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/weights/read ( type:  Identity )
# 338/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_variance ( type:  Const )
# 339/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 340/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_mean ( type:  Const )
# 341/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 342/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/beta ( type:  Const )
# 343/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/beta/read ( type:  Identity )
# 344/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/gamma ( type:  Const )
# 345/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/gamma/read ( type:  Identity )
# 346/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/depthwise_weights ( type:  Const )
# 347/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/depthwise_weights/read ( type:  Identity )
# 348/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_variance ( type:  Const )
# 349/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_variance/read ( type:  Identity )
# 350/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_mean ( type:  Const )
# 351/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/moving_mean/read ( type:  Identity )
# 352/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/beta ( type:  Const )
# 353/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/beta/read ( type:  Identity )
# 354/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/gamma ( type:  Const )
# 355/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/gamma/read ( type:  Identity )
# 356/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/weights ( type:  Const )
# 357/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/weights/read ( type:  Identity )
# 358/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_variance ( type:  Const )
# 359/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_variance/read ( type:  Identity )
# 360/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_mean ( type:  Const )
# 361/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/moving_mean/read ( type:  Identity )
# 362/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/beta ( type:  Const )
# 363/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/beta/read ( type:  Identity )
# 364/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/gamma ( type:  Const )
# 365/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/gamma/read ( type:  Identity )
# 366/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/weights ( type:  Const )
# 367/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/weights/read ( type:  Identity )
# 368/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance ( type:  Const )
# 369/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read ( type:  Identity )
# 370/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean ( type:  Const )
# 371/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read ( type:  Identity )
# 372/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/beta ( type:  Const )
# 373/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read ( type:  Identity )
# 374/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/gamma ( type:  Const )
# 375/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read ( type:  Identity )
# 376/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/weights ( type:  Const )
# 377/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/weights/read ( type:  Identity )
# 378/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance ( type:  Const )
# 379/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 380/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean ( type:  Const )
# 381/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 382/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta ( type:  Const )
# 383/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read ( type:  Identity )
# 384/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma ( type:  Const )
# 385/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 386/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise_weights ( type:  Const )
# 387/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise_weights/read ( type:  Identity )
# 388/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance ( type:  Const )
# 389/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 390/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean ( type:  Const )
# 391/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 392/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/beta ( type:  Const )
# 393/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/beta/read ( type:  Identity )
# 394/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma ( type:  Const )
# 395/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma/read ( type:  Identity )
# 396/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/weights ( type:  Const )
# 397/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/weights/read ( type:  Identity )
# 398/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_variance ( type:  Const )
# 399/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_variance/read ( type:  Identity )
# 400/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_mean ( type:  Const )
# 401/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/moving_mean/read ( type:  Identity )
# 402/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/beta ( type:  Const )
# 403/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/beta/read ( type:  Identity )
# 404/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/gamma ( type:  Const )
# 405/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/gamma/read ( type:  Identity )
# 406/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/weights ( type:  Const )
# 407/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/weights/read ( type:  Identity )
# 408/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_variance ( type:  Const )
# 409/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_variance/read ( type:  Identity )
# 410/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_mean ( type:  Const )
# 411/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/moving_mean/read ( type:  Identity )
# 412/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta ( type:  Const )
# 413/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta/read ( type:  Identity )
# 414/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma ( type:  Const )
# 415/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma/read ( type:  Identity )
# 416/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise_weights ( type:  Const )
# 417/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise_weights/read ( type:  Identity )
# 418/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_variance ( type:  Const )
# 419/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_variance/read ( type:  Identity )
# 420/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_mean ( type:  Const )
# 421/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/moving_mean/read ( type:  Identity )
# 422/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/beta ( type:  Const )
# 423/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/beta/read ( type:  Identity )
# 424/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma ( type:  Const )
# 425/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma/read ( type:  Identity )
# 426/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/weights ( type:  Const )
# 427/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/expand/weights/read ( type:  Identity )
# 428/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_variance ( type:  Const )
# 429/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_variance/read ( type:  Identity )
# 430/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm/moving_mean ( type:  Const )
# ...
# 1110/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/Conv2D ( type:  Conv2D )
# 1111/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1112/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/project/Identity ( type:  Identity )
# 1113/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/add ( type:  Add )
# 1114/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_15/output ( type:  Identity )
# 1115/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/input ( type:  Identity )
# 1116/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/Conv2D ( type:  Conv2D )
# 1117/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1118/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expand/Relu6 ( type:  Relu6 )
# 1119/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/expansion_output ( type:  Identity )
# 1120/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1121/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1122/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/Relu6 ( type:  Relu6 )
# 1123/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise_output ( type:  Identity )
# 1124/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/Conv2D ( type:  Conv2D )
# 1125/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1126/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/project/Identity ( type:  Identity )
# 1127/1260: Analysing op name: FeatureExtractor/MobilenetV2/expanded_conv_16/output ( type:  Identity )
# 1128/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/Conv2D ( type:  Conv2D )
# 1129/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1130/1260: Analysing op name: FeatureExtractor/MobilenetV2/Conv_1/Relu6 ( type:  Relu6 )
# 1131/1260: Analysing op name: BoxPredictor_1/Shape_1 ( type:  Shape )
# 1132/1260: Analysing op name: BoxPredictor_1/strided_slice_1 ( type:  StridedSlice )
# 1133/1260: Analysing op name: BoxPredictor_1/Reshape_1/shape ( type:  Pack )
# 1134/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1135/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1136/1260: Analysing op name: BoxPredictor_1/ClassPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1137/1260: Analysing op name: BoxPredictor_1/ClassPredictor/Conv2D ( type:  Conv2D )
# 1138/1260: Analysing op name: BoxPredictor_1/ClassPredictor/BiasAdd ( type:  BiasAdd )
# 1139/1260: Analysing op name: BoxPredictor_1/Reshape_1 ( type:  Reshape )
# 1140/1260: Analysing op name: BoxPredictor_1/Shape ( type:  Shape )
# 1141/1260: Analysing op name: BoxPredictor_1/strided_slice ( type:  StridedSlice )
# 1142/1260: Analysing op name: BoxPredictor_1/Reshape/shape ( type:  Pack )
# 1143/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1144/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1145/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1146/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/Conv2D ( type:  Conv2D )
# 1147/1260: Analysing op name: BoxPredictor_1/BoxEncodingPredictor/BiasAdd ( type:  BiasAdd )
# 1148/1260: Analysing op name: BoxPredictor_1/Reshape ( type:  Reshape )
# 1149/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/Conv2D ( type:  Conv2D )
# 1150/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1151/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/Relu6 ( type:  Relu6 )
# 1152/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1153/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1154/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512_depthwise/Relu6 ( type:  Relu6 )
# 1155/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/Conv2D ( type:  Conv2D )
# 1156/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1157/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/Relu6 ( type:  Relu6 )
# 1158/1260: Analysing op name: BoxPredictor_2/Shape_1 ( type:  Shape )
# 1159/1260: Analysing op name: BoxPredictor_2/strided_slice_1 ( type:  StridedSlice )
# 1160/1260: Analysing op name: BoxPredictor_2/Reshape_1/shape ( type:  Pack )
# 1161/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1162/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1163/1260: Analysing op name: BoxPredictor_2/ClassPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1164/1260: Analysing op name: BoxPredictor_2/ClassPredictor/Conv2D ( type:  Conv2D )
# 1165/1260: Analysing op name: BoxPredictor_2/ClassPredictor/BiasAdd ( type:  BiasAdd )
# 1166/1260: Analysing op name: BoxPredictor_2/Reshape_1 ( type:  Reshape )
# 1167/1260: Analysing op name: BoxPredictor_2/Shape ( type:  Shape )
# 1168/1260: Analysing op name: BoxPredictor_2/strided_slice ( type:  StridedSlice )
# 1169/1260: Analysing op name: BoxPredictor_2/Reshape/shape ( type:  Pack )
# 1170/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1171/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1172/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1173/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/Conv2D ( type:  Conv2D )
# 1174/1260: Analysing op name: BoxPredictor_2/BoxEncodingPredictor/BiasAdd ( type:  BiasAdd )
# 1175/1260: Analysing op name: BoxPredictor_2/Reshape ( type:  Reshape )
# 1176/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/Conv2D ( type:  Conv2D )
# 1177/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1178/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/Relu6 ( type:  Relu6 )
# 1179/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1180/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1181/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256_depthwise/Relu6 ( type:  Relu6 )
# 1182/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/Conv2D ( type:  Conv2D )
# 1183/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1184/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/Relu6 ( type:  Relu6 )
# 1185/1260: Analysing op name: BoxPredictor_3/Shape_1 ( type:  Shape )
# 1186/1260: Analysing op name: BoxPredictor_3/strided_slice_1 ( type:  StridedSlice )
# 1187/1260: Analysing op name: BoxPredictor_3/Reshape_1/shape ( type:  Pack )
# 1188/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1189/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1190/1260: Analysing op name: BoxPredictor_3/ClassPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1191/1260: Analysing op name: BoxPredictor_3/ClassPredictor/Conv2D ( type:  Conv2D )
# 1192/1260: Analysing op name: BoxPredictor_3/ClassPredictor/BiasAdd ( type:  BiasAdd )
# 1193/1260: Analysing op name: BoxPredictor_3/Reshape_1 ( type:  Reshape )
# 1194/1260: Analysing op name: BoxPredictor_3/Shape ( type:  Shape )
# 1195/1260: Analysing op name: BoxPredictor_3/strided_slice ( type:  StridedSlice )
# 1196/1260: Analysing op name: BoxPredictor_3/Reshape/shape ( type:  Pack )
# 1197/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1198/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1199/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1200/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/Conv2D ( type:  Conv2D )
# 1201/1260: Analysing op name: BoxPredictor_3/BoxEncodingPredictor/BiasAdd ( type:  BiasAdd )
# 1202/1260: Analysing op name: BoxPredictor_3/Reshape ( type:  Reshape )
# 1203/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/Conv2D ( type:  Conv2D )
# 1204/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1205/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/Relu6 ( type:  Relu6 )
# 1206/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1207/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1208/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256_depthwise/Relu6 ( type:  Relu6 )
# 1209/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/Conv2D ( type:  Conv2D )
# 1210/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1211/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/Relu6 ( type:  Relu6 )
# 1212/1260: Analysing op name: BoxPredictor_4/Shape_1 ( type:  Shape )
# 1213/1260: Analysing op name: BoxPredictor_4/strided_slice_1 ( type:  StridedSlice )
# 1214/1260: Analysing op name: BoxPredictor_4/Reshape_1/shape ( type:  Pack )
# 1215/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1216/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1217/1260: Analysing op name: BoxPredictor_4/ClassPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1218/1260: Analysing op name: BoxPredictor_4/ClassPredictor/Conv2D ( type:  Conv2D )
# 1219/1260: Analysing op name: BoxPredictor_4/ClassPredictor/BiasAdd ( type:  BiasAdd )
# 1220/1260: Analysing op name: BoxPredictor_4/Reshape_1 ( type:  Reshape )
# 1221/1260: Analysing op name: BoxPredictor_4/Shape ( type:  Shape )
# 1222/1260: Analysing op name: BoxPredictor_4/strided_slice ( type:  StridedSlice )
# 1223/1260: Analysing op name: BoxPredictor_4/Reshape/shape ( type:  Pack )
# 1224/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1225/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1226/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1227/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/Conv2D ( type:  Conv2D )
# 1228/1260: Analysing op name: BoxPredictor_4/BoxEncodingPredictor/BiasAdd ( type:  BiasAdd )
# 1229/1260: Analysing op name: BoxPredictor_4/Reshape ( type:  Reshape )
# 1230/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/Conv2D ( type:  Conv2D )
# 1231/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1232/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/Relu6 ( type:  Relu6 )
# 1233/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1234/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1235/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128_depthwise/Relu6 ( type:  Relu6 )
# 1236/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/Conv2D ( type:  Conv2D )
# 1237/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1238/1260: Analysing op name: FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/Relu6 ( type:  Relu6 )
# 1239/1260: Analysing op name: BoxPredictor_5/Shape_1 ( type:  Shape )
# 1240/1260: Analysing op name: BoxPredictor_5/strided_slice_1 ( type:  StridedSlice )
# 1241/1260: Analysing op name: BoxPredictor_5/Reshape_1/shape ( type:  Pack )
# 1242/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1243/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1244/1260: Analysing op name: BoxPredictor_5/ClassPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1245/1260: Analysing op name: BoxPredictor_5/ClassPredictor/Conv2D ( type:  Conv2D )
# 1246/1260: Analysing op name: BoxPredictor_5/ClassPredictor/BiasAdd ( type:  BiasAdd )
# 1247/1260: Analysing op name: BoxPredictor_5/Reshape_1 ( type:  Reshape )
# 1248/1260: Analysing op name: concat_1 ( type:  ConcatV2 )
# 1249/1260: Analysing op name: Postprocessor/scale_logits ( type:  RealDiv )
# 1250/1260: Analysing op name: Postprocessor/convert_scores ( type:  Sigmoid )
# 1251/1260: Analysing op name: BoxPredictor_5/Shape ( type:  Shape )
# 1252/1260: Analysing op name: BoxPredictor_5/strided_slice ( type:  StridedSlice )
# 1253/1260: Analysing op name: BoxPredictor_5/Reshape/shape ( type:  Pack )
# 1254/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/depthwise ( type:  DepthwiseConv2dNative )
# 1255/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 1256/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor_depthwise/Relu6 ( type:  Relu6 )
# 1257/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/Conv2D ( type:  Conv2D )
# 1258/1260: Analysing op name: BoxPredictor_5/BoxEncodingPredictor/BiasAdd ( type:  BiasAdd )
# 1259/1260: Analysing op name: BoxPredictor_5/Reshape ( type:  Reshape )
# 1260/1260: Analysing op name: concat ( type:  ConcatV2 )
# Translation to CoreML spec completed. Now compiling and saving the CoreML model.
#
#  Core ML model generated. Saved at location: MobileNetV2_SSDLite.mlmodel
#
# Core ML input(s):
#  [name: "Preprocessor__sub__0"
# type {
#   imageType {
#     width: 300
#     height: 300
#     colorSpace: RGB
#   }
# }
# ]
# Core ML output(s):
#  [name: "Postprocessor__convert_scores__0"
# type {
#   multiArrayType {
#     dataType: DOUBLE
#   }
# }
# , name: "concat__0"
# type {
#   multiArrayType {
#     shape: 4
#     shape: 1917
#     shape: 1
#     dataType: DOUBLE
#   }
# }
# ]

# %% [markdown]
# ### Cleaning it up
#
# Let’s rename the input to "image" and the two outputs to "scores" and "boxes", respectively. This requires using the model’s spec object:

# %%
spec = ssd_model.get_spec()

spec.description.input[0].name = "image"
spec.description.input[0].shortDescription = "Input image"
spec.description.output[0].name = "scores"
spec.description.output[0].shortDescription = "Predicted class scores for each bounding box"
spec.description.output[1].name = "boxes"
spec.description.output[1].shortDescription = "Predicted coordinates for each bounding box"

# %% [markdown]
# It’s not enough to change these names in the spec.description. Any layers that are connected to the old input or output names must now use the new names too. Likewise for the object that handles the image preprocessing.

# %%
input_mlmodel = input_tensor.replace(":", "__").replace("/", "__")
class_output_mlmodel = class_output_tensor.replace(":", "__").replace("/", "__")
bbox_output_mlmodel = bbox_output_tensor.replace(":", "__").replace("/", "__")

for i in range(len(spec.neuralNetwork.layers)):
    if spec.neuralNetwork.layers[i].input[0] == input_mlmodel:
        spec.neuralNetwork.layers[i].input[0] = "image"
    if spec.neuralNetwork.layers[i].output[0] == class_output_mlmodel:
        spec.neuralNetwork.layers[i].output[0] = "scores"
    if spec.neuralNetwork.layers[i].output[0] == bbox_output_mlmodel:
        spec.neuralNetwork.layers[i].output[0] = "boxes"

spec.neuralNetwork.preprocessing[0].featureName = "image"

# %% [markdown]
# If we look at the outputs using print(spec.description), the "scores" output correctly shows up as a multi-array but its shape is not filled in:

# %%
num_classes = 9
num_anchors = 1917
spec.description.output[0].type.multiArrayType.shape.append(num_classes + 1)
spec.description.output[0].type.multiArrayType.shape.append(num_anchors)

# %%
spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(spec)
ssd_model = coremltools.models.MLModel(spec)
ssd_model.save(coreml_model_path)

# %% [markdown]
# ### Decoding the bounding box predictions

# %%
input_width = 300
input_height = 300
num_classes = 9
num_anchors = 1917

def get_anchors(graph, tensor_name):
    image_tensor = graph.get_tensor_by_name("image_tensor:0")
    box_corners_tensor = graph.get_tensor_by_name(tensor_name)
    box_corners = sess.run(box_corners_tensor, feed_dict={
        image_tensor: np.zeros((1, input_height, input_width, 3))})

    ymin, xmin, ymax, xmax = np.transpose(box_corners)
    width = xmax - xmin
    height = ymax - ymin
    ycenter = ymin + height / 2.
    xcenter = xmin + width / 2.
    return np.stack([ycenter, xcenter, height, width])

anchors_tensor = "Concatenate/concat:0"
with the_graph.as_default():
    with tf.Session(graph=the_graph) as sess:
        anchors = get_anchors(the_graph, anchors_tensor)

# %% [markdown]
# ### Decoding inside the Core ML model

# %%
input_features = [
    ("scores", datatypes.Array(num_classes + 1, num_anchors, 1)),
    ("boxes", datatypes.Array(4, num_anchors, 1))
]

output_features = [
    ("raw_confidence", datatypes.Array(num_anchors, num_classes)),
    ("raw_coordinates", datatypes.Array(num_anchors, 4))
]

builder = neural_network.NeuralNetworkBuilder(input_features, output_features)

# %%
builder.add_permute(name="permute_scores",
                    dim=(0, 3, 2, 1),
                    input_name="scores",
                    output_name="permute_scores_output")

# %%
builder.add_slice(name="slice_scores",
                  input_name="permute_scores_output",
                  output_name="raw_confidence",
                  axis="width",
                  start_index=1,
                  end_index=num_classes + 1)

# %%
builder.add_slice(name="slice_yx",
                  input_name="boxes",
                  output_name="slice_yx_output",
                  axis="channel",
                  start_index=0,
                  end_index=2)

# %%
builder.add_elementwise(name="scale_yx",
                        input_names="slice_yx_output",
                        output_name="scale_yx_output",
                        mode="MULTIPLY",
                        alpha=0.1)

# %%
anchors_yx = np.expand_dims(anchors[:2, :], axis=-1)
anchors_hw = np.expand_dims(anchors[2:, :], axis=-1)
builder.add_load_constant(name="anchors_yx",
                          output_name="anchors_yx",
                          constant_value=anchors_yx,
                          shape=[2, num_anchors, 1])

builder.add_load_constant(name="anchors_hw",
                          output_name="anchors_hw",
                          constant_value=anchors_hw,
                          shape=[2, num_anchors, 1])

# %%
builder.add_elementwise(name="yw_times_hw",
                        input_names=["scale_yx_output", "anchors_hw"],
                        output_name="yw_times_hw_output",
                        mode="MULTIPLY")

builder.add_elementwise(name="decoded_yx",
                        input_names=["yw_times_hw_output", "anchors_yx"],
                        output_name="decoded_yx_output",
                        mode="ADD")

# %%
builder.add_slice(name="slice_hw",
                  input_name="boxes",
                  output_name="slice_hw_output",
                  axis="channel",
                  start_index=2,
                  end_index=4)

builder.add_elementwise(name="scale_hw",
                        input_names="slice_hw_output",
                        output_name="scale_hw_output",
                        mode="MULTIPLY",
                        alpha=0.2)

# %%
builder.add_unary(name="exp_hw",
                  input_name="scale_hw_output",
                  output_name="exp_hw_output",
                  mode="exp")

builder.add_elementwise(name="decoded_hw",
                        input_names=["exp_hw_output", "anchors_hw"],
                        output_name="decoded_hw_output",
                        mode="MULTIPLY")

# %%
builder.add_slice(name="slice_y",
                  input_name="decoded_yx_output",
                  output_name="slice_y_output",
                  axis="channel",
                  start_index=0,
                  end_index=1)

builder.add_slice(name="slice_x",
                  input_name="decoded_yx_output",
                  output_name="slice_x_output",
                  axis="channel",
                  start_index=1,
                  end_index=2)

builder.add_slice(name="slice_h",
                  input_name="decoded_hw_output",
                  output_name="slice_h_output",
                  axis="channel",
                  start_index=0,
                  end_index=1)

builder.add_slice(name="slice_w",
                  input_name="decoded_hw_output",
                  output_name="slice_w_output",
                  axis="channel",
                  start_index=1,
                  end_index=2)

builder.add_elementwise(name="concat",
                        input_names=["slice_x_output", "slice_y_output", 
                                     "slice_w_output", "slice_h_output"],
                        output_name="concat_output",
                        mode="CONCAT")

# %%
builder.add_permute(name="permute_output",
                    dim=(0, 3, 2, 1),
                    input_name="concat_output",
                    output_name="raw_coordinates")

# %%
decoder_model = coremltools.models.MLModel(builder.spec)
decoder_model.save("Decoder.mlmodel")

# %% [markdown]
# ### Non-maximum suppression

# %%
nms_spec = coremltools.proto.Model_pb2.Model()
nms_spec.specificationVersion = 3

# %%
for i in range(2):
    decoder_output = decoder_model._spec.description.output[i].SerializeToString()

    nms_spec.description.input.add()
    nms_spec.description.input[i].ParseFromString(decoder_output)

    nms_spec.description.output.add()
    nms_spec.description.output[i].ParseFromString(decoder_output)
    
nms_spec.description.output[0].name = "confidence"
nms_spec.description.output[1].name = "coordinates"

# %%
output_sizes = [num_classes, 4]
for i in range(2):
    ma_type = nms_spec.description.output[i].type.multiArrayType
    ma_type.shapeRange.sizeRanges.add()
    ma_type.shapeRange.sizeRanges[0].lowerBound = 0
    ma_type.shapeRange.sizeRanges[0].upperBound = -1
    ma_type.shapeRange.sizeRanges.add()
    ma_type.shapeRange.sizeRanges[1].lowerBound = output_sizes[i]
    ma_type.shapeRange.sizeRanges[1].upperBound = output_sizes[i]
    del ma_type.shape[:]

# %%
nms = nms_spec.nonMaximumSuppression
nms.confidenceInputFeatureName = "raw_confidence"
nms.coordinatesInputFeatureName = "raw_coordinates"
nms.confidenceOutputFeatureName = "confidence"
nms.coordinatesOutputFeatureName = "coordinates"
nms.iouThresholdInputFeatureName = "iouThreshold"
nms.confidenceThresholdInputFeatureName = "confidenceThreshold"

# %%
default_iou_threshold = 0.6
default_confidence_threshold = 0.4
nms.iouThreshold = default_iou_threshold
nms.confidenceThreshold = default_confidence_threshold

# %%
nms.pickTop.perClass = True

# %%
labels = np.loadtxt("labelmap.txt", dtype=str, delimiter="\n")
nms.stringClassLabels.vector.extend(labels)

# %%
nms_model = coremltools.models.MLModel(nms_spec)
nms_model.save("NMS.mlmodel")

# %% [markdown]
# ### Putting it together into a pipeline

# %%
input_features = [ ("image", datatypes.Array(3, 300, 300)),
                   ("iouThreshold", datatypes.Double()),
                   ("confidenceThreshold", datatypes.Double()) ]

output_features = [ "confidence", "coordinates" ]

pipeline = Pipeline(input_features, output_features)

# %%
ssd_output = ssd_model._spec.description.output
ssd_output[0].type.multiArrayType.shape[:] = [num_classes + 1, num_anchors, 1]
ssd_output[1].type.multiArrayType.shape[:] = [4, num_anchors, 1]

# %%
pipeline.add_model(ssd_model)
pipeline.add_model(decoder_model)
pipeline.add_model(nms_model)

# %%
pipeline.spec.description.input[0].ParseFromString(
    ssd_model._spec.description.input[0].SerializeToString())
pipeline.spec.description.output[0].ParseFromString(
    nms_model._spec.description.output[0].SerializeToString())
pipeline.spec.description.output[1].ParseFromString(
    nms_model._spec.description.output[1].SerializeToString())
# Out:
# 43

# %%
pipeline.spec.description.input[1].shortDescription = "(optional) IOU Threshold override"
pipeline.spec.description.input[2].shortDescription = "(optional) Confidence Threshold override"
pipeline.spec.description.output[0].shortDescription = u"Boxes \xd7 Class confidence"
pipeline.spec.description.output[1].shortDescription = u"Boxes \xd7 [x, y, width, height] (relative to image size)"

# %%
pipeline.spec.description.metadata.versionString = "ssdlite_mobilenet_v2_coco_2018_05_09"
pipeline.spec.description.metadata.shortDescription = "MobileNetV2 + SSDLite, trained on our spider dataset"
pipeline.spec.description.metadata.author = "Converted to Core ML by Matthijs Hollemans"
pipeline.spec.description.metadata.license = "https://github.com/tensorflow/models/blob/master/research/object_detection"

# %%
user_defined_metadata = {
    "classes": ",".join(labels),
    "iou_threshold": str(default_iou_threshold),
    "confidence_threshold": str(default_confidence_threshold)
}
pipeline.spec.description.metadata.userDefined.update(user_defined_metadata)

# %%
pipeline.spec.specificationVersion = 3
final_model = coremltools.models.MLModel(pipeline.spec)
final_model.save(coreml_model_path)
